# %%
#import libaries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#load data into panda dataframe
df = pd.read_csv('D:\DataScience@DKB\Iris.csv')
#print the first 5 rows
print(df.head(5))
#shows basic statistics of data
df.describe()
df.shape
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# (150, 6)

# %%
#subset data 
df1 = df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
#print(df1)
#calculate correlation between dimensions
cor = df1.corr()
#print(cor)
#show correlations on heatmap
sns.heatmap(cor, square=True)
plt.show()

# %%
def get_column(A,j):
    return [A_i[j] for A_i in A]  #j-tes Element der Zeile A_i für jede Zeile A_i

# %%
#plot die Daten

_, num_columns = np.shape(data)
fig, ax = plt.subplots(num_columns, num_columns, sharex='col', sharey='row')

for i in range(num_columns):
        for j in range(num_columns):
        
            #Scatterplot von column_j auf der x-Achse und column_i auf der y-Achse
            if i != j: ax[i][j].scatter(get_column(data, j), get_column(data, i))
        
            #wenn i == j, zeige den Namen der Datenreihe an
            else: ax[i][j].annotate("series " + str(i), (0.5,0.5),
                           xycoords='axes fraction',
                           ha="center", va="center")
                        
plt.show()
